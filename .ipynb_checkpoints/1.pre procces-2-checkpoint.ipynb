# %%
import pandas as pd
df= pd.read_csv('flySFO Full.csv')
df=pd.DataFrame(df.text)
df.dropna(inplace=True)

# %%
df['text'] = [entry.lower() for entry in df['text']]

# %%
from nltk.tokenize import word_tokenize
df['text']= [word_tokenize(entry) for entry in df['text']]

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/ray/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn
from collections import defaultdict
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.corpus import stopwords
filterword=['http','sfo','san francisco','francisco','san','muslimban','flysfo','letthelawyersin','letthefamiliesout',
           'let','nobannowall','trump','sf','tweet','twitter','sanfrancisco','pic','california','ban','protest','get',
           'go','come','hey','day','today','muslim','lawyer','nomuslimban','delta','sfoprotest','yestarday','protester',
           'hello','yes','protestors','year','realdonaldtrump','india','federal','muslimbanprotest','virginamerica',
           'lilou','nancypelosi','kamalaharris','airline','avgeek','boeing','letthefamilesout','dhsgov','bei','iranian',
           'aclu','gon','pig','therapy','america','cbp','noban','sfpd','fascism','jfkairport','rt','gavinnewsom','holiday',
           'southwestair','alaskaair','nyc','say','land','head','international','guy','city','detain','detainee','tell',
           'happen','sit','flylaxairport','americanair','photo','try','bay','want','start','visit','really','order','set',
           'think','use','week','weekend','report','night','tonight','morning','apcointl','hear','SouthwestAir','wow','ca',
           'detained','bye','yemeni','yemen','unite','united','refugee','resist','jfk','int','intl','la','oh','work','west',
            'flysjc','hi','tommorow','iflyoaklhand','iflyoakland','tomorrow','weareunited','manchester','spot','bound',
            'oakland','thomascookuk','wagbridge','oakland','ops','seatacairport','sanctuary','pdx','Vegas','london','ipa',
            'unconstitutional','aircanada','seattle','vega','State','airport','yesterday','wagbrigade','coast','east','iran',
            'iah area','mypov','tag','nomuslimbansfo','lax','roamaroo','jerrybrowngov','virgin','iah','birthday','id','god',
            'queen','flyfrontier','ewrairport','virginatlantic','manairport','yeah','ncapco','sustaincities','area','joke',
            'neefusa','jet','jetsetter','fran','state','thanksgiving','chicago','yay','ya','na','rdu','lufthansa','stab',
            'january','monday','austin','saturday','Los Angeles','Los angeles','jetblue','month','sunday','qantas','woman',
            'season','red','ta','till','goodbye','earthjustice','naaap','sea','man','atl','pre','summer','friday','thousand',
            'blue','eye','second','app','stick','country','book','klm','canada','chant','mco','boston','parallel','couple',
            'york','court','end','mom','dc','bit','sjc','potus','tour','mayoredlee','ha','leg','wag','layovertip','cali',
            'ord','sydney','phx','oc','bama','Obama','obama','hawaii','sxsw','en','paris','usa','afternoon','picture','las',
            'heathrowairport','yvrairport','refugeeswelcome','wo','newark' ,'denver','mexico','portland','south','china',
            'ny','phoenix','yo','headin','retweet','resisttrump','christmas','dallas','vancouver','europe','ce','texas',
            'gdl','tpe','sd','cancun','polaris','singaporeair','zero','ii','airlinesdotorg','american','southwest','flypdx',
            'north','cc','psp','whistler','atx','mnl','taiwan','bdl','peakperformers','milwaukee','typecon','nbcbayarea',
            'notinourname','girl','dreamliner','cvgairport','fyi','june','im','centurion','pm','hsn','ibiza','lbc','asia',
            'italy','visitaustintx','byebyesf','dfwairport','atlairport','lady','aviationweek','mile','boeingairplanes','syd',
            'email','single','midnight','nation','thursday','rduairport','hireheroesusa','freeiran','jackiespeier','citizen',
            'sandiegoairport','lasairport','japan','ur','sfohttps','ah','senfeinstein','alaska','bird','human','join','band',
            'senfeinstein','senfeinstein','los angeles','faa','hireheroesusa','airporttwitter','missionaccomplished','style',
            'family','tuesday','shot','tale','ask','bring','allow','video','evacuate','release','airfrance','apiaviation',
            'flytpa','vacation','status','job','question','post','repost','team','thing','dm','hrzone','shhrpjobs','party',
            'comply','catch','dog','friend','congrats','green','word','inaugural','ago','stuckatairport','aaaedelivers',
            'airportscouncil','cancel','probabaly','sunrise','history','trip','travel','air','aviation','Literally','step',
            'Ttot','ttot','plane','trivia','teen','board','long','news','runwayrehab','strand','change','hope','rise',
            'tower','xlek','gronud','bruno','https','cathaypacificus','fiji','finland','kedoubleseoul','october','learn',
            'yearroundbula','tucson','Karl the fog','Karthefog','crew','felt','add','know','non','contest','folk','wheel',
            'civil','golden','awww','sustainability','sfogreenscreen','sky','probably','excited','saw','hong kong','maybe',
            'hong','kong','april','fijiairways','travelskills','celebrate','odds','panama','beingunited','copamatch','send',
            'uaifsbasesfo','rio','korea','pas','wind','make','fly','flight','anytime','traffic','rally','excite','hat','refuel',
            'encounter','admission','forget','win','include','game','chance','event','play','replay','airfield','ticket',
            'cancellation','drive','driver','hire','career','dispatcher','communications','review','expert','technology',
            'planner','environmental','cloud','aciworld','supv','tech','bigdata','act','remain','karlthefog','rain','bro',
            'berlin','taipei','helsinki','president','orlando','roxane','merry','stpatricksday','anniversary','copaairlines',
            'elderly','planespotting','trail','reply','seoul','skyclub','halloween','lunar','bandit','florida','spare','total',
            'thread','airtravel','world','kinda','fight','officially','mobile','launch','begin','actually','meet','bless',
            'belated','mean','fall','buddy','forward','formation','stroll','sun','figure','follow','town','update','legal',
            'anneincal','bed','instead','idea','mad','cathay','myfrenchblue','peep','decide','empire','illegal','arrow',
            'circling','detaining','pilot','touch','suppose','snow','average','yuszela','dusk','sunny','rainbow','sunset',
            'need','consider','usually','turn','deplane','wave','sfac','route','wish','lhr','sister','finnair','stun','movie',
            'mr','jennifer','count','ok','lates','okay','face','patmorita','sir','rid','ct','finallyalthough','present','kid',
            'confabedu','landing','takeoff','landin','different','loud','bayarea','absolutely','power','definitely','phone',
            'kciairport','possible','airbus','light','orleans','scrooge','steve','houston','userresearchldn','skydeck','napa',
            'pacific','nwsbayarea','tree','person','vote','hot','minor','plan','fact','wi','watch','reason','issue','force',
            'express','hel','kanchhuu','placard','chilly','september','amaze','ride','bayvibes','illustration','lot','sleep',
            'barclaycardtravel','manager','low','approach','avgeeks','avgeekhttps','norcal','hang','brief','repavement','msp',
            'renovation','fuel','direct','pal','deport','dalycity','office','enter','share','operate','ish','nearly','retire',
            'refuse','omg','changiairport','fossil','spirit','classic','paul','incheonairport','renewables','detention','jose',
            'prior','bostonlogan','honey','life','attorney','airporttwins','invent','read','deny','cathaypacific','lotta',
            'letthemin','wedding','joelbackaler','sfgiants','colorful','peoplewatching','codeshare','fiancé','patience','atc',
            'unacceptable','effective','home','sweet','woohoo','ebay','warm','real','sure','soon','lgaairport','fake','shower',
            'occupy','grab','happythanksgiving','rod','wooo','darn','upgrade','wife','son','ali','tire','faanews','woz','ice',
            'volatility','sanfran','mother','washington','fresnoairport','icymi','castorm','airportthrowdown','ooh','groovy',
            'ugh','altusfws','fellow','cockpit','techie','docusign','comm','piaware','openstreetmap','evening','dude','jason',
            'enrollment','stevewoz','unamerican','obey','unamerican','qatarairways','swissairlines','letfamiliesout','haha',
            'traveltuesday','chaos','minus','national','hq','authority','notinmyname','congratulation','pet','shift','cute',
            'michael','handsome','xoxo','tcrawford','cell','pit','sfolasjfk','valentine','ppl','fresno','neo','pls','volunteer',
            'katyturnbc','flymco','investigate','foxrentcar','letlawyersin','tbt','nap','nursing','globalentry','million',
            'enforcement','avgeekhttp','festivity','totally','camera','tristan','globalpriority','netherlands','tail','katy',
            'hand','example','counsel','revenue','helsinkiairport','tcairlinesuk','schiphol','homework','officeralbie','imagine',
            'aw','amdays','downtown','touchdown','cdg','aircraft','disneyland','hbaskas','melissa','groundhog','spring','jam',
            'bigotry','woot','arrives','lovin','goto','xxxx','maddow','stormwatch','travelersbff','loic','nerdbird','jowyang',
            'backup','queenoftheskies','damn','metal','den','nazis','republican','article','racism','islamophobia','solidarity',
            'tripwireinc','sansforensics','issaintl','thecyberwire','journalist','philly','tune','til','eo','happyhowlidays',
            'leaf','oppose','volcano','momma','thotcon','aug','congestion','bearrepublic','anchorbrewing','anchor','mechanical',
            'ale','gbbrewingco','lagunitasbeer','calicraft','hnl','prioritypasscom','candrinkservicestartearly','athens','fail',
            'ultimate','dfw','ivar','czech','pilsner','gbbrewingco','jetson','diego','worldfamouspatlyons','rocketship','xx',
            'steal','thelowryhotel','plus','conference','unruly','curious','ate','child','montreal','wingfriday','brixton',
            'virginamericaoffical','foot','rocket','personalcapital','flier','departurehttps','qbr','dreamforce','repaving',
            'abqsunport','authorial','catastrophe','army','briansolis','waltdisneyworld','cjmcginnis','indy','hnd','berm',
            'weareallimmigrants','hop','sept','ewr','fam','hefeweizen','blonde','maibock','moderntimesbeer','pale','genitals',
            'ireland','tsapre','download','allnighter','ntsb','honolulu','satero','illegally','cook','thomas','divert','guess',
            'dance','pour','nationalpetday','disaster','wednesday','cabin','usatoday','sunshine','island','construction','stuff',
            'firestonewalker' ,'sierranevada','meeting','door' ,'copy','racer','woof','annual','invite','message','honor',
            'authority','dublin','flyontairport','individual','wildfire','worth','stresshttps','howlidays','awake','pushback',
            'past','incident','homeward','fridayfeeling','farewell','fortpointbeer','realize','global','hydrate','yup','fleet',
            'dont','file','toronto','iad','hashtags','daly','sell','yep','ramp','glass','unitedhttps','flyairnz','era','twice',
            'grand','hyatt','jobsearch','psa','brother','senatedems','housedemocrats','unconstit','unitedairlines','travelban',
            'premier','link','heathrow','lame','jealous','los','angeles','bridge','facebook','flyontairport','sfpelosi','slc',
            'napafarmsmarket','france','hertz','immoral','fascist','naaahrnatl','lptravelnews','accord','march','alarm','smoke',
            'little','thx','daily','sfbos','base','ba','gif','ai','miami','poor','atlanta','absolute','denairport','shoe','refill',
            'dang','hrbartender','middle','staralliance','westjet','karl','fllflyer','fort','oscar','munoz','voucher','ring',
            'drakesbeer','starbucks','kim','neveragain','white','die','breeze','oak','break','breaking','live','heart','exert',
            'number','bock','hoppy','july','training','kudos','ahh','nowallnoban','ruin','throw','cbssf','brigade','tho','series',
            'resistance','kill','dhs','captain','emirates','dreampolaris','inhumane','flt','yr','john','chrislhayes','windy',
            'advise','action','immigrantswelcome','mobpassport','asiana','double','ua','analyst','beijing','nobannowallhttps',
            ' riot','thecenturionlounge','singapore','tow','cawx','yikes','holy','nashville','askamex','veronicadlcruz','moon',
            'elebration','ship','millbrae','phlairport','iflymia','film','austinairport','ren','norcalfires','cltairport','rad',
            'spotter','atcday','headijg','nationalpigday','kat','bayfront','flystl','flypal','beingunitedhttps','hahaha','grow',
            'melair','detainees','legally','clip','hysterical','ksa','await','hazy','fieldworkbrewco','yum','shatters','company',
            'compost','tartinebakery','airportshttps','soooo','paintball','sanfranciscoi','avg','aa','pax','smallblessings',
            'jesus','ceiling','andre','temp','andre','reno','turf','equip','ive','myhometown','bc','wks','mia','editorial','fr',
            'stoppresidentbannon','unlawfully','cx','letthemout','phxskyharbor','voyage','shanghai','college','btw','ktvu',
            'manila','lgb','uk','british','icegov','omaha','yummy','northern','throwbackthursday','yea','canadian','retweeted',
            'obby','viewglass','gosh','dhabi','etihadairways','abu','internment','clara','flypal','press','paxex','juice','bna',
            'oimeetsgrrrl','sfgate','bleisure','hyatttweets','grandhyatt','hahaha','flughafen','weekendwanderlust','story',
            'continue','support','intern','site','celebration','pack','big','data','deck','clinic','medical','seminar','greet',
            'cuz','defy','nazi','frontiercare','tampa','namaste','airberlin','plz','ribbon','actual','dozen','nurse','age',
            'em','sacramento','parent','sa','aerlingus','centurionlounge','depart','pretty','provide','host','kind','heat',
            'old','smell','luck','journey','talk','official','away','climb','protecttranskids','warrior','cold','panel','treat',
            'energy','cybersecurity','despite','sign','executive','roadway','avoid','garage','schedule','taxiway','opportunity',
            'cool','return','businesstravel','remote','community','awesome','truck','speed','forever','mic','glad','conveniently',
            'save','ready','extra','good','drinking','place','heading','point','far','help','miss','fan','listen','smooth',
            'later','hold','moment','installation','sound','clear','partner','request','member','right','observe','deserve',
            'rule','welcome','aboard','sorry','lol','near','requirement','record','announce','feedback','exit','nursery',
            'look','compare','car','sarah','speedy','beignet','way','sad','siliconvalley','happy','explain','choose','indication',
            'logo','fun','sight','kick','responsibly','commute','comms','like','quite','center','runway','closure','eep','msy',
            'repair','seriously','reporting','mexicocity','zagrebairport','fog','visibility','ridiculous','regard','hub','bump',
            'view','new','announces','emergency','mind','currently','defend','chillin','tokyo','husband','strong','meal','lose',
            'block','problem','duee','communication','shame','madness','hate','filter','kiddos','scimitar','offer','compliance',
            'airportguide','affect','steam','rate','entry','award','travelalert','ahead','random','wake','mess','announcement',
            'apparently','yellowcabsf','georgia','crash','hitler','channel','remnant','salesforcetower','bos','rush','lane',
            'gooseisland','enforce','episode','current','agree','secret','permit','relate','rock','account','window','camp',
            'trap','pressure','cincinnati','color','body','december','surprise','impact','represent','racist','road','traveler',
            'flow','counting','roster','fee','aselder','newspiritofunited','hpjg','prevail','respect','goose','duet','pro','pdt',
            'condition','stuck','flyer','situation','law','worker','alpinebeerco','blizzard','limit','liftoff','page','witness',
            'urge','ruling','exec','miracle','prepare','ridiculous','protect','presidenttrump','idiots','bear','suncountryair',
            'xenophobia','cairsfba','pouring','upstairs','brette','brit','awse','worktravel','airway','stopmuslimbanusa','whe',
            'refugeesarewelcomehere','operation','blame','bday','cease','dueprocess','stout','round','rerouted','warning','grind',
            'unusual','cooler','aeromexico','jfkhttps','degree','deltaskyclub','winter','matter','attendee','beat','vegas','pd',
            'judge','commission','deal','ouija','wonder','dtweetin','amber','frankfurt','remember','anymore','airplane','insane',
            'case','blast','fair','answer','travelaware','sale','emirate','suspicious','jurisdiction','almanacbeer','gorgeous',
            'cause','demand','wonderful','dear','delicious','final','finally','safe','cake','small','feature','waste','storm',
            'earlier','early','quiet','heavy','fortunate','especially','apology','clearing','dependent','pick','voice','grind'
            'wan','corner','cumulonimbus','inflightvideo','traveller','noncompliance','sanctary','omsborder','welcometothebay',
            'combine','jetbridge','black','solid','forecast','indicate','grant','injustice','constitution','sfbusinesstimes',
            'house','finish','rebooked','cut','machine','lift','background','travelnews','bs','representation','malaysia','feed',
            'neat','murica','comp','slight','remedy','shannoncoulter','group','proud','director','wont','mark','believe','baby',
            'laugh','tonite','apocalypse','buzzerkeley','ughhh','shutitdown','stadium','winglet','malmo','pant','nightbeattv',
            'regime','muslimbanhttps','intervene','defiance','tiooooooonnnnnnnn','summerfest','lagunitas','sweden','wing',
            'ascent','bully','roo','judicial','wildcat','festbier','crisp','meckcounty','windowgazing','wrong','winterbock',
            'draft','able','diannefeinstein','jk','demagogue','hateful','photos','belgian','feministing','muslinban','bitter',
            'humantraffickingawareness','lethefamiliesout','bluemoonbrewco','fightforgood','indivisiblesf','wear','pa','stone',
            'dust','gesture','unless','program','symbology','elysianbrewing','stonebrewing','om','trash','brave','policy',
            'sooner','bread','perk','escalate','arbitrary','create','sfoairporthttps','recognize','fll','vegetarian','workout',
            'redskin','ourrevolution','bmaradiant','thebay','shoutout','reflection','firm','ignore','utah','variable','fear',
            'irreparable','yogapreneur','spread','harm','mosaic','airportzen','closer','jog','soldier','gender','minneapolis',
            'crime','airside','reality','race','half','pull','redeye','beach','survive','software','nightmare','onlyinsf',
            'bet','investigation','funny','note','mention','wan','circle','sfoairport','complaint','sfoairport','suggestion',
            'prep','sanctuaryforall','raise','alert','goldengatebridge','common','true','track','separate','require','ups',
            'statement','peetscoffee','notice','outside','effect','card','unfortunately','scene','push','load','flyswiss','max',
            'biz','respond','mercnews','butler','additional','network','orange','building','avis','manage','worry','engine',
            'specific','directly','patio','project','freak','pleasure','supervisor','tip','map','write','dream','build','weird',
            'observation','whats','gross','everybody','patrol','lili','student','frustration','exist','fresh','adventure','sexy',
            'sfgov','jaketapper','contempt','complete','cover','wed','barely','boy','date','indairport','lie','adjust','hell',
            'increase','startup','dad','model','screw','mix','valley','chat','tv','county','letthelawersin','squealandgiggle',
            'undercover','jump','enemy','swedenattack','megan','heaven','health','multiple','ground','tarmac','priority',
            'kelly','hotel','socal','speakeasybeer','implement','behing','contact','daddy','prohibition','sensetive','cop',
            'domestic','hereticbrew','wale','airchina',' level','twin','evil','unlawful','completely','level','literally',
            'metropolis','heartless','stillwaiting','subject','successful','djt','shut','exhaust','bullshit','brew','tyranny',
            'administration','hef','entire','philadelphia','senschumer','biwasummit','inhumanity','airportblowout','memory',
            'xpresspa','poweroutage','java','sour','congresspersons','inside','lager','weather','riot','switch','socali',
            'Suspicious','package','dread','unexpected','nohatenofear','redevelopment','speaker','haphazard','incoming',
            'cancelled','australia','pleasanton','sculpin','dignity','bottle','unhappy','monitoring','grapefruit','ge',
            'follower','hr','suck','shit','hopefully','fuck','wtf','pumped','flash','deplorable','precheck','retirement',
            'advises','ballastpoint','customer','absurd','angry','crazy','hamburg','msg','chowder','jaguar','solemnly',
            'happeningnow','hit','typewriter','wingseatwednesday','dodger','favor','foundersbrewing','nationwide','future',
            'amsterdam','significant','remind','bookstore','dick','americanexpress','fountain','plaaaaaaaane','bengold',
            'airtran','unclear','advance','airportparking','locate','hrs','improve','walker','stanfordalumni','unplanned',
            'fully','collaboration','curb','turtle','ijustwanttogethome','flyunited','delineators','proceed','handle',
            'museum','understand','talentnet','training','living','compensation','massive','course','upset','voicemail',
            'gohawaii','initial','tougher','stephkorey','kci','lucky','constant','heard','joepine','mtgs','mex','pty',
            'airbusintheus','wfsbtraffic','rehab','strange','santa','fault','obscure','mommy','sjpoxley','maui','assume',
            'agent','celebrity','philidelphia','letterhead','industrial','roughly','catering','notification','flood'
           ]

#country,reach,pick,phone,phone
#trash,program,perk,
#maintenance,livery,pickup,info,planning,stand,nonstop,fix,available,serve,wine,wonderful,open,feature,fail



#program
#great,crazy,large,wine,switch,precheck,laptop,guest,regular,priority,border,bottle,water


for index,entry in enumerate(df['text']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            if str(word_Final) not in filterword:
                Final_words.append(word_Final)
#             for i in filterword:
#                 if str(word_Final)!=str(i):
#                     Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    df.loc[index,'text_final']=str(Final_words)

# %%
df.dropna(inplace=True)

# %%
df.to_csv('full_clean.csv')

# %%
df
# Out:
#                                                     text  \
# 0      [i, 'm, at, san, francisco, international, air...
# 1      [hey, @, flysfo, your, lt, parking, is, awful,...
# 2      [see, ya, #, sanfran, you, were, a, good, litt...
# 3      [avoid, roadway, congestion, and, conveniently...
# 4      [heyyyyyyy, (, @, san, francisco, internationa...
# ...                                                  ...
# 24035     [both, versions, will, eat, your, children, .]
# 24036  [@, flysfo, almost, two, hours, waiting, for, ...
# 24037  [the, last, @, united, flight, to, omaha, in, ...
# 24038  [long, day, ., (, @, san, francisco, internati...
# 24039  [肥来, (, @, san, francisco, international, airp...
#
#                                               text_final
# 0                                                     []
# 1      ['lt', 'parking', 'awful', 'per', 'fastrack', ...
# 2                                                ['see']
# ...
